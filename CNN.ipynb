# %%
## 인공지능을 위한 수학 1
## Term Project : Classifying Electronic Devices (8 classes)
## Custom Data Image Classification using PyTorch


## Module Import
from __future__ import print_function
from torch import nn, optim, cuda
from torch.utils import data
from torchvision import datasets, transforms
import torch.nn.functional as F
import time
import torch

import cv2
import numpy as np
import matplotlib.pyplot as plt

import glob
import PIL


## Google Drive Mount

from google.colab import drive
drive.mount('/content/drive')


## Trainig Parameter Setup

batch_size = 2
device = 'cuda' if cuda.is_available() else 'cpu'
max_epoch = 100
sub_fname = '12190369_b2_e100.txt'
val = True ## Change this to 'False' if you just want to try test images.


print(f'Training Custom Dataset on {device}\n{"="*44}')

## Train Dataset 구축

### Image/Label List 생성

all_image = glob.glob('/content/drive/MyDrive/samples/train/*/*.jpg')
all_image.sort

## 사용할 Image 파일들의 경로가 제대로 생성되었나 확인
#print(all_image)

## Image, Label List 설정
image_list=[]
label_list=[]


for item in all_image:
  image_list.append(cv2.imread(item))
  label_folder = item.split('/')[-2]
  label_list.append(int(label_folder))


### Train Tensor 생성 및 train_datset 객체 생성
all_image_tensor = torch.from_numpy((np.array(image_list).transpose(0,3,1,2)).astype(np.float32))
target_tensor = torch.tensor(np.array(label_list))

train_dataset = torch.utils.data.TensorDataset(all_image_tensor, target_tensor)

#print(type(train_dataset))


## Validation Dataset 구축

### Image/Label List 생성

if val:

  val_image = glob.glob('/content/drive/MyDrive/samples/train/*/*.jpg')
  val_image.sort

  val_image_list=[]
  val_label_list=[]


  for item in val_image:
    val_image_list.append(cv2.imread(item))
    label_folder = item.split('/')[-2]
    val_label_list.append(int(label_folder))

  val_image_list = image_list
  val_label_list = label_list


### Validation Tensor 생성 및 val_datset 객체 생성

  val_image_tensor = torch.from_numpy((np.array(val_image_list).transpose(0,3,1,2)).astype(np.float32))
  val_target_tensor = torch.tensor(np.array(val_label_list))



  # 클래스 개수에 따라 val_target_tensor의 크기를 (이미지 개수,)에서 (이미지 개수, 클래스 개수)로 변경
  val_dataset = torch.utils.data.TensorDataset(val_image_tensor, val_target_tensor)


## Test Dataset 파일 위치 지정
test_image = glob.glob('/content/drive/MyDrive/samples/test_all/*.jpg')
test_image.sort()

## Data loader
train_loader = data.DataLoader(dataset=train_dataset,
                               batch_size=batch_size,
                               shuffle=True)
val_loader = data.DataLoader(dataset=val_dataset,
                              batch_size=batch_size,
                              shuffle=False)


## Network Architecture Definition

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.l0 = nn.LayerNorm((3, 64, 64))
    self.l1 = nn.Conv2d(3, 16, 3, padding = 1)
    self.l2 = nn.Conv2d(16,16, 3, padding = 1)
    self.l3 = nn.Conv2d(16, 32, 3, padding = 1)
    self.l4 = nn.Linear(2048, 120)
    self.l5 = nn.Linear(120, 8)

   #torch.nn.init.xavier_normal_(self.l1.weight.data)

  def forward(self, x):
    x = self.l0(x)
    x = F.relu(self.l1(x))
    #print("1st size", x.size())
    x = F.max_pool2d(x, 2)
    #print("2nd size", x.size())
    x = F.relu(self.l2(x))
    x = F.relu(self.l3(x))
    x = F.max_pool2d(x, 2)
    #print("3rd size", x.size())
    x = F.max_pool2d(x, 2)
    x = x.view(-1, 2048)
    x = F.relu(self.l4(x))
    return self.l5(x)

## Network Load


model = Net()
model.to(device)


## 특정 레이어의 웨이트를 출력하여 확인하고 싶을 때
#print(model.l1.weight)


## Training Setup

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.5)


## 모델 전체 weight parameter들의 이름과 값을 확인하고 싶을 때
#for param_tensor in model.state_dict():
#  print(param_tensor, "\t", model.state_dict()[param_tensor])



## Train Function

## 이 코드에서는 epoch 값을 인자로 받아 중간 결과 출력 시 사용.

def train(epoch):
  model.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    data, target = data.to(device), target.to(device)
    optimizer.zero_grad()
    output = model(data)
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()

    # 10 iteration 마다 현재 loss값 출력
    if batch_idx % 10 == 0:
      print('Train Epoch : {} | Batch Status : {}/{} ({:.0f}%) | Loss : {:.6f}'.format(
          epoch, batch_idx*len(data), len(train_loader.dataset),
          100. * batch_idx / len(train_loader), loss.item()))


## Test Function

## 매 epoch마다, test dataset에 대한 성능 측정

def val():
  model.eval()
  test_loss = 0
  correct = 0
  for data, target in val_loader:
    data, target = data.to(device), target.to(device)
    output = model(data)

    # sum up batch loss
    test_loss += criterion(output, target).item()

    # get the index of the max
    pred = output.data.max(1, keepdim=True)[1]
    correct += pred.eq(target.data.view_as(pred)).cpu().sum()

  test_loss /= len(val_loader.dataset)
  print(f'==================\nValidation set: Average loss : {test_loss:.4f}, Accuracy : {correct}/{len(val_loader.dataset)}'
        f'({100. * correct / len(val_loader.dataset):.0f}%)')




def test_submission():
  result_list = list(-1 for i in range(800))
  conf_list = list(-1 for i in range(800))

  model.eval()

  for item in test_image:

    img_name = int(item.split('/')[-1][:-4])
    print('Processing the image number', img_name, '.....')
    cur_tensor = torch.from_numpy((np.array(cv2.imread(item)).transpose(2,0,1)).astype(np.float32)).unsqueeze(0)
    cur_tensor = cur_tensor.to(device)
    output = model(cur_tensor)

    # get the index of the max
    pred = output.data.max(1, keepdim=True)[1]
    softmax_vec = torch.nn.functional.softmax(output.data, dim=1)
    #print(softmax_vec)
   # print(softmax_vec.size)
    conf = '%.05f'%softmax_vec[0][pred[0]]
  #  print(conf)
    result_list[img_name] = pred[0]
    conf_list[img_name] = conf

  mytxt = open(sub_fname, 'a')
  sub_cnt = 0

  for j in range(800):
    mytxt.write('%04d.jpg   %d   %s\n'%(sub_cnt, result_list[j], conf_list[j]))
    #mytxt.write('%04d.jpg   %d\n'%(sub_cnt, j[0]))
    sub_cnt+=1
  mytxt.close()


## Main

if __name__ == '__main__':

  ## time 모듈들은 각 epoch 마다 걸린 시간을 측정
  since = time.time()

  for epoch in range(1, max_epoch+1):
    epoch_start = time.time()

    train(epoch)

    m, s = divmod(time.time() - epoch_start, 60)
    print(f'Training time: {m:.0f}m {s:.0f}s')

    if val:
      val()

    m, s = divmod(time.time() - epoch_start, 60)
    print(f'Tesing time: {m:.0f}m {s:.0f}s')

  m, s = divmod(time.time() - epoch_start, 60)
  print(f'Total time : {m:.0f}m {s: .0f}s \nModel was trained on {device}!')

  print(f'Evaluation begins...')
  test_submission()
  print(f'Evaluation completed. The submittion file has been saved.')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Train Epoch : 75 | Batch Status : 1360/3200 (42%) | Loss : 0.000017
# Train Epoch : 75 | Batch Status : 1380/3200 (43%) | Loss : 0.000188
# Train Epoch : 75 | Batch Status : 1400/3200 (44%) | Loss : 0.000433
# Train Epoch : 75 | Batch Status : 1420/3200 (44%) | Loss : 0.000470
# Train Epoch : 75 | Batch Status : 1440/3200 (45%) | Loss : 0.001538
# Train Epoch : 75 | Batch Status : 1460/3200 (46%) | Loss : 0.001385
# Train Epoch : 75 | Batch Status : 1480/3200 (46%) | Loss : 0.000031
# Train Epoch : 75 | Batch Status : 1500/3200 (47%) | Loss : 0.000001
# Train Epoch : 75 | Batch Status : 1520/3200 (48%) | Loss : 0.000122
# Train Epoch : 75 | Batch Status : 1540/3200 (48%) | Loss : 0.000054
# Train Epoch : 75 | Batch Status : 1560/3200 (49%) | Loss : 0.000301
# Train Epoch : 75 | Batch Status : 1580/3200 (49%) | Loss : 0.000063
# Train Epoch : 75 | Batch Status : 1600/3200 (50%) | Loss : 0.000039
# Train Epoch : 75 | Batch Status : 1620/3200 (51%) | Loss : 0.000009
# Train Epoch : 75 | Batch Status : 1640/3200 (51%) | Loss : 0.000137
# Train Epoch : 75 | Batch Status : 1660/3200 (52%) | Loss : 0.000016
# Train Epoch : 75 | Batch Status : 1680/3200 (52%) | Loss : 0.000003
# Train Epoch : 75 | Batch Status : 1700/3200 (53%) | Loss : 0.000002
# Train Epoch : 75 | Batch Status : 1720/3200 (54%) | Loss : 0.000514
# Train Epoch : 75 | Batch Status : 1740/3200 (54%) | Loss : 0.000000
# Train Epoch : 75 | Batch Status : 1760/3200 (55%) | Loss : 0.000113
# Train Epoch : 75 | Batch Status : 1780/3200 (56%) | Loss : 0.000164
# Train Epoch : 75 | Batch Status : 1800/3200 (56%) | Loss : 0.000325
# Train Epoch : 75 | Batch Status : 1820/3200 (57%) | Loss : 0.000001
# Train Epoch : 75 | Batch Status : 1840/3200 (58%) | Loss : 0.000368
# Train Epoch : 75 | Batch Status : 1860/3200 (58%) | Loss : 0.000078
# Train Epoch : 75 | Batch Status : 1880/3200 (59%) | Loss : 0.000002
# Train Epoch : 75 | Batch Status : 1900/3200 (59%) | Loss : 0.000152
# Train Epoch : 75 | Batch Status : 1920/3200 (60%) | Loss : 0.000008
# Train Epoch : 75 | Batch Status : 1940/3200 (61%) | Loss : 0.000306
# Train Epoch : 75 | Batch Status : 1960/3200 (61%) | Loss : 0.000001
# Train Epoch : 75 | Batch Status : 1980/3200 (62%) | Loss : 0.000555
# Train Epoch : 75 | Batch Status : 2000/3200 (62%) | Loss : 0.000056
# Train Epoch : 75 | Batch Status : 2020/3200 (63%) | Loss : 0.000215
# Train Epoch : 75 | Batch Status : 2040/3200 (64%) | Loss : 0.000284
# Train Epoch : 75 | Batch Status : 2060/3200 (64%) | Loss : 0.000237
# Train Epoch : 75 | Batch Status : 2080/3200 (65%) | Loss : 0.000267
# Train Epoch : 75 | Batch Status : 2100/3200 (66%) | Loss : 0.000115
# Train Epoch : 75 | Batch Status : 2120/3200 (66%) | Loss : 0.000013
# Train Epoch : 75 | Batch Status : 2140/3200 (67%) | Loss : 0.000000
# Train Epoch : 75 | Batch Status : 2160/3200 (68%) | Loss : 0.000012
# Train Epoch : 75 | Batch Status : 2180/3200 (68%) | Loss : 0.000066
# Train Epoch : 75 | Batch Status : 2200/3200 (69%) | Loss : 0.000365
# Train Epoch : 75 | Batch Status : 2220/3200 (69%) | Loss : 0.000013
# Train Epoch : 75 | Batch Status : 2240/3200 (70%) | Loss : 0.000135
# Train Epoch : 75 | Batch Status : 2260/3200 (71%) | Loss : 0.000020
# Train Epoch : 75 | Batch Status : 2280/3200 (71%) | Loss : 0.000162
# Train Epoch : 75 | Batch Status : 2300/3200 (72%) | Loss : 0.000691
# Train Epoch : 75 | Batch Status : 2320/3200 (72%) | Loss : 0.000053
# Train Epoch : 75 | Batch Status : 2340/3200 (73%) | Loss : 0.000011
# Train Epoch : 75 | Batch Status : 2360/3200 (74%) | Loss : 0.001027
# Train Epoch : 75 | Batch Status : 2380/3200 (74%) | Loss : 0.000005
# Train Epoch : 75 | Batch Status : 2400/3200 (75%) | Loss : 0.000267
# Train Epoch : 75 | Batch Status : 2420/3200 (76%) | Loss : 0.000047
# Train Epoch : 75 | Batch Status : 2440/3200 (76%) | Loss : 0.000001
# Train Epoch : 75 | Batch Status : 2460/3200 (77%) | Loss : 0.000239
# Train Epoch : 75 | Batch Status : 2480/3200 (78%) | Loss : 0.000236
# Train Epoch : 75 | Batch Status : 2500/3200 (78%) | Loss : 0.000495
# Train Epoch : 75 | Batch Status : 2520/3200 (79%) | Loss : 0.000013
# Train Epoch : 75 | Batch Status : 2540/3200 (79%) | Loss : 0.000000
# Train Epoch : 75 | Batch Status : 2560/3200 (80%) | Loss : 0.000003
# Train Epoch : 75 | Batch Status : 2580/3200 (81%) | Loss : 0.000053
# Train Epoch : 75 | Batch Status : 2600/3200 (81%) | Loss : 0.000006
# Train Epoch : 75 | Batch Status : 2620/3200 (82%) | Loss : 0.000000
# Train Epoch : 75 | Batch Status : 2640/3200 (82%) | Loss : 0.000166
# Train Epoch : 75 | Batch Status : 2660/3200 (83%) | Loss : 0.000240
# Train Epoch : 75 | Batch Status : 2680/3200 (84%) | Loss : 0.000009
# Train Epoch : 75 | Batch Status : 2700/3200 (84%) | Loss : 0.000204
# Train Epoch : 75 | Batch Status : 2720/3200 (85%) | Loss : 0.000360
# Train Epoch : 75 | Batch Status : 2740/3200 (86%) | Loss : 0.000813
# Train Epoch : 75 | Batch Status : 2760/3200 (86%) | Loss : 0.000002
# Train Epoch : 75 | Batch Status : 2780/3200 (87%) | Loss : 0.000003
# Train Epoch : 75 | Batch Status : 2800/3200 (88%) | Loss : 0.000079
# Train Epoch : 75 | Batch Status : 2820/3200 (88%) | Loss : 0.576958
# Train Epoch : 75 | Batch Status : 2840/3200 (89%) | Loss : 0.000002
# Train Epoch : 75 | Batch Status : 2860/3200 (89%) | Loss : 0.000000
# Train Epoch : 75 | Batch Status : 2880/3200 (90%) | Loss : 0.000050
# Train Epoch : 75 | Batch Status : 2900/3200 (91%) | Loss : 0.000004
# Train Epoch : 75 | Batch Status : 2920/3200 (91%) | Loss : 0.000030
# Train Epoch : 75 | Batch Status : 2940/3200 (92%) | Loss : 0.000001
# Train Epoch : 75 | Batch Status : 2960/3200 (92%) | Loss : 0.000051
# Train Epoch : 75 | Batch Status : 2980/3200 (93%) | Loss : 0.000462
# Train Epoch : 75 | Batch Status : 3000/3200 (94%) | Loss : 0.000151
# Train Epoch : 75 | Batch Status : 3020/3200 (94%) | Loss : 0.000165
# Train Epoch : 75 | Batch Status : 3040/3200 (95%) | Loss : 0.000000
# Train Epoch : 75 | Batch Status : 3060/3200 (96%) | Loss : 0.000318
# Train Epoch : 75 | Batch Status : 3080/3200 (96%) | Loss : 0.000148
# Train Epoch : 75 | Batch Status : 3100/3200 (97%) | Loss : 0.000001
# Train Epoch : 75 | Batch Status : 3120/3200 (98%) | Loss : 0.000591
# Train Epoch : 75 | Batch Status : 3140/3200 (98%) | Loss : 0.000019
# Train Epoch : 75 | Batch Status : 3160/3200 (99%) | Loss : 0.001006
# Train Epoch : 75 | Batch Status : 3180/3200 (99%) | Loss : 0.000016
# Training time: 0m 3s
# ==================
# Validation set: Average loss : 0.0005, Accuracy : 3198/3200(100%)
# Tesing time: 0m 5s
# Train Epoch : 76 | Batch Status : 0/3200 (0%) | Loss : 0.000073
# Train Epoch : 76 | Batch Status : 20/3200 (1%) | Loss : 0.000057
# Train Epoch : 76 | Batch Status : 40/3200 (1%) | Loss : 0.000012
# Train Epoch : 76 | Batch Status : 60/3200 (2%) | Loss : 0.000008
# Train Epoch : 76 | Batch Status : 80/3200 (2%) | Loss : 0.000000
# Train Epoch : 76 | Batch Status : 100/3200 (3%) | Loss : 0.000089
# Train Epoch : 76 | Batch Status : 120/3200 (4%) | Loss : 0.000022
# Train Epoch : 76 | Batch Status : 140/3200 (4%) | Loss : 0.000009
# Train Epoch : 76 | Batch Status : 160/3200 (5%) | Loss : 0.000007
# Train Epoch : 76 | Batch Status : 180/3200 (6%) | Loss : 0.000366
# Train Epoch : 76 | Batch Status : 200/3200 (6%) | Loss : 0.000000
# Train Epoch : 76 | Batch Status : 220/3200 (7%) | Loss : 0.000038
# Train Epoch : 76 | Batch Status : 240/3200 (8%) | Loss : 0.000033
# Train Epoch : 76 | Batch Status : 260/3200 (8%) | Loss : 0.000031
# Train Epoch : 76 | Batch Status : 280/3200 (9%) | Loss : 0.000111
# Train Epoch : 76 | Batch Status : 300/3200 (9%) | Loss : 0.000098
# Train Epoch : 76 | Batch Status : 320/3200 (10%) | Loss : 0.000128
# Train Epoch : 76 | Batch Status : 340/3200 (11%) | Loss : 0.000179
# Train Epoch : 76 | Batch Status : 360/3200 (11%) | Loss : 0.000352
# Train Epoch : 77 | Batch Status : 240/3200 (8%) | Loss : 0.000039
# Train Epoch : 77 | Batch Status : 260/3200 (8%) | Loss : 0.000043
# Train Epoch : 77 | Batch Status : 280/3200 (9%) | Loss : 0.000030
# Train Epoch : 77 | Batch Status : 300/3200 (9%) | Loss : 0.000005
# Train Epoch : 77 | Batch Status : 320/3200 (10%) | Loss : 0.000055
# Train Epoch : 77 | Batch Status : 340/3200 (11%) | Loss : 0.000366
# Train Epoch : 77 | Batch Status : 360/3200 (11%) | Loss : 0.000028
# Train Epoch : 77 | Batch Status : 380/3200 (12%) | Loss : 0.000220
# Train Epoch : 77 | Batch Status : 400/3200 (12%) | Loss : 0.000000
# Train Epoch : 77 | Batch Status : 420/3200 (13%) | Loss : 0.000270
# Train Epoch : 77 | Batch Status : 440/3200 (14%) | Loss : 0.000000
# Train Epoch : 77 | Batch Status : 460/3200 (14%) | Loss : 0.000167
# Train Epoch : 77 | Batch Status : 480/3200 (15%) | Loss : 0.000054
# Train Epoch : 77 | Batch Status : 500/3200 (16%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 520/3200 (16%) | Loss : 0.000047
# Train Epoch : 77 | Batch Status : 540/3200 (17%) | Loss : 0.000335
# Train Epoch : 77 | Batch Status : 560/3200 (18%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 580/3200 (18%) | Loss : 0.000000
# Train Epoch : 77 | Batch Status : 600/3200 (19%) | Loss : 0.000174
# Train Epoch : 77 | Batch Status : 620/3200 (19%) | Loss : 0.000016
# Train Epoch : 77 | Batch Status : 640/3200 (20%) | Loss : 0.000078
# Train Epoch : 77 | Batch Status : 660/3200 (21%) | Loss : 0.000751
# Train Epoch : 77 | Batch Status : 680/3200 (21%) | Loss : 0.000242
# Train Epoch : 77 | Batch Status : 700/3200 (22%) | Loss : 0.000165
# Train Epoch : 77 | Batch Status : 720/3200 (22%) | Loss : 0.000000
# Train Epoch : 77 | Batch Status : 740/3200 (23%) | Loss : 0.000015
# Train Epoch : 77 | Batch Status : 760/3200 (24%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 780/3200 (24%) | Loss : 0.000012
# Train Epoch : 77 | Batch Status : 800/3200 (25%) | Loss : 0.001551
# Train Epoch : 77 | Batch Status : 820/3200 (26%) | Loss : 0.000083
# Train Epoch : 77 | Batch Status : 840/3200 (26%) | Loss : 0.000369
# Train Epoch : 77 | Batch Status : 860/3200 (27%) | Loss : 0.000122
# Train Epoch : 77 | Batch Status : 880/3200 (28%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 900/3200 (28%) | Loss : 0.000765
# Train Epoch : 77 | Batch Status : 920/3200 (29%) | Loss : 0.000611
# Train Epoch : 77 | Batch Status : 940/3200 (29%) | Loss : 0.000126
# Train Epoch : 77 | Batch Status : 960/3200 (30%) | Loss : 0.000283
# Train Epoch : 77 | Batch Status : 980/3200 (31%) | Loss : 0.000154
# Train Epoch : 77 | Batch Status : 1000/3200 (31%) | Loss : 0.001219
# Train Epoch : 77 | Batch Status : 1020/3200 (32%) | Loss : 0.000003
# Train Epoch : 77 | Batch Status : 1040/3200 (32%) | Loss : 0.000071
# Train Epoch : 77 | Batch Status : 1060/3200 (33%) | Loss : 0.000024
# Train Epoch : 77 | Batch Status : 1080/3200 (34%) | Loss : 0.000285
# Train Epoch : 77 | Batch Status : 1100/3200 (34%) | Loss : 0.000102
# Train Epoch : 77 | Batch Status : 1120/3200 (35%) | Loss : 0.000003
# Train Epoch : 77 | Batch Status : 1140/3200 (36%) | Loss : 0.000002
# Train Epoch : 77 | Batch Status : 1160/3200 (36%) | Loss : 0.000100
# Train Epoch : 77 | Batch Status : 1180/3200 (37%) | Loss : 0.000205
# Train Epoch : 77 | Batch Status : 1200/3200 (38%) | Loss : 0.000009
# Train Epoch : 77 | Batch Status : 1220/3200 (38%) | Loss : 0.000028
# Train Epoch : 77 | Batch Status : 1240/3200 (39%) | Loss : 0.000443
# Train Epoch : 77 | Batch Status : 1260/3200 (39%) | Loss : 0.000221
# Train Epoch : 77 | Batch Status : 1280/3200 (40%) | Loss : 0.000048
# Train Epoch : 77 | Batch Status : 1300/3200 (41%) | Loss : 0.000860
# Train Epoch : 77 | Batch Status : 1320/3200 (41%) | Loss : 0.000143
# Train Epoch : 77 | Batch Status : 1340/3200 (42%) | Loss : 0.000027
# Train Epoch : 77 | Batch Status : 1360/3200 (42%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 1380/3200 (43%) | Loss : 0.000000
# Train Epoch : 77 | Batch Status : 1400/3200 (44%) | Loss : 0.000252
# Train Epoch : 77 | Batch Status : 1420/3200 (44%) | Loss : 0.000164
# Train Epoch : 77 | Batch Status : 1440/3200 (45%) | Loss : 0.000934
# Train Epoch : 77 | Batch Status : 1460/3200 (46%) | Loss : 0.000002
# Train Epoch : 77 | Batch Status : 1480/3200 (46%) | Loss : 0.000003
# Train Epoch : 77 | Batch Status : 1500/3200 (47%) | Loss : 0.000021
# Train Epoch : 77 | Batch Status : 1520/3200 (48%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 1540/3200 (48%) | Loss : 0.000249
# Train Epoch : 77 | Batch Status : 1560/3200 (49%) | Loss : 0.001811
# Train Epoch : 77 | Batch Status : 1580/3200 (49%) | Loss : 0.000307
# Train Epoch : 77 | Batch Status : 1600/3200 (50%) | Loss : 0.000280
# Train Epoch : 77 | Batch Status : 1620/3200 (51%) | Loss : 0.000082
# Train Epoch : 77 | Batch Status : 1640/3200 (51%) | Loss : 0.000019
# Train Epoch : 77 | Batch Status : 1660/3200 (52%) | Loss : 0.000054
# Train Epoch : 77 | Batch Status : 1680/3200 (52%) | Loss : 0.000063
# Train Epoch : 77 | Batch Status : 1700/3200 (53%) | Loss : 0.001465
# Train Epoch : 77 | Batch Status : 1720/3200 (54%) | Loss : 0.000000
# Train Epoch : 77 | Batch Status : 1740/3200 (54%) | Loss : 0.000005
# Train Epoch : 77 | Batch Status : 1760/3200 (55%) | Loss : 0.000005
# Train Epoch : 77 | Batch Status : 2540/3200 (79%) | Loss : 0.000333
# Train Epoch : 77 | Batch Status : 2560/3200 (80%) | Loss : 0.000060
# Train Epoch : 77 | Batch Status : 2580/3200 (81%) | Loss : 0.000000
# Train Epoch : 77 | Batch Status : 2600/3200 (81%) | Loss : 0.000004
# Train Epoch : 77 | Batch Status : 2620/3200 (82%) | Loss : 0.000437
# Train Epoch : 77 | Batch Status : 2640/3200 (82%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 2660/3200 (83%) | Loss : 0.000004
# Train Epoch : 77 | Batch Status : 2680/3200 (84%) | Loss : 0.000024
# Train Epoch : 77 | Batch Status : 2700/3200 (84%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 2720/3200 (85%) | Loss : 0.000262
# Train Epoch : 77 | Batch Status : 2740/3200 (86%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 2760/3200 (86%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 2780/3200 (87%) | Loss : 0.000281
# Train Epoch : 77 | Batch Status : 2800/3200 (88%) | Loss : 0.000000
# Train Epoch : 77 | Batch Status : 2820/3200 (88%) | Loss : 0.000038
# Train Epoch : 77 | Batch Status : 2840/3200 (89%) | Loss : 0.000080
# Train Epoch : 77 | Batch Status : 2860/3200 (89%) | Loss : 0.000002
# Train Epoch : 77 | Batch Status : 2880/3200 (90%) | Loss : 0.000014
# Train Epoch : 77 | Batch Status : 2900/3200 (91%) | Loss : 0.000016
# Train Epoch : 77 | Batch Status : 2920/3200 (91%) | Loss : 0.000000
# Train Epoch : 77 | Batch Status : 2940/3200 (92%) | Loss : 0.000000
# Train Epoch : 77 | Batch Status : 2960/3200 (92%) | Loss : 0.000232
# Train Epoch : 77 | Batch Status : 2980/3200 (93%) | Loss : 0.000004
# Train Epoch : 77 | Batch Status : 3000/3200 (94%) | Loss : 0.000067
# Train Epoch : 77 | Batch Status : 3020/3200 (94%) | Loss : 0.000013
# Train Epoch : 77 | Batch Status : 3040/3200 (95%) | Loss : 0.000002
# Train Epoch : 77 | Batch Status : 3060/3200 (96%) | Loss : 0.000063
# Train Epoch : 77 | Batch Status : 3080/3200 (96%) | Loss : 0.000011
# Train Epoch : 77 | Batch Status : 3100/3200 (97%) | Loss : 0.000940
# Train Epoch : 77 | Batch Status : 3120/3200 (98%) | Loss : 0.000001
# Train Epoch : 77 | Batch Status : 3140/3200 (98%) | Loss : 0.000100
# Train Epoch : 77 | Batch Status : 3160/3200 (99%) | Loss : 0.000259
# Train Epoch : 77 | Batch Status : 3180/3200 (99%) | Loss : 0.000183
# Training time: 0m 3s
# ==================
# Validation set: Average loss : 0.0006, Accuracy : 3198/3200(100%)
# Tesing time: 0m 5s
# Train Epoch : 78 | Batch Status : 0/3200 (0%) | Loss : 0.000295
# Train Epoch : 78 | Batch Status : 20/3200 (1%) | Loss : 0.000242
# Train Epoch : 78 | Batch Status : 40/3200 (1%) | Loss : 0.000199
# Train Epoch : 78 | Batch Status : 60/3200 (2%) | Loss : 0.000028
# Train Epoch : 78 | Batch Status : 80/3200 (2%) | Loss : 0.000211
# Train Epoch : 78 | Batch Status : 100/3200 (3%) | Loss : 0.000002
# Train Epoch : 78 | Batch Status : 120/3200 (4%) | Loss : 0.000021
# Train Epoch : 78 | Batch Status : 140/3200 (4%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 160/3200 (5%) | Loss : 0.000094
# Train Epoch : 78 | Batch Status : 180/3200 (6%) | Loss : 0.000020
# Train Epoch : 78 | Batch Status : 200/3200 (6%) | Loss : 0.000004
# Train Epoch : 78 | Batch Status : 220/3200 (7%) | Loss : 0.000300
# Train Epoch : 78 | Batch Status : 240/3200 (8%) | Loss : 0.000584
# Train Epoch : 78 | Batch Status : 260/3200 (8%) | Loss : 0.000846
# Train Epoch : 78 | Batch Status : 280/3200 (9%) | Loss : 0.000420
# Train Epoch : 78 | Batch Status : 300/3200 (9%) | Loss : 0.000154
# Train Epoch : 78 | Batch Status : 320/3200 (10%) | Loss : 0.001222
# Train Epoch : 78 | Batch Status : 340/3200 (11%) | Loss : 0.000012
# Train Epoch : 78 | Batch Status : 360/3200 (11%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 380/3200 (12%) | Loss : 0.000043
# Train Epoch : 78 | Batch Status : 400/3200 (12%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 420/3200 (13%) | Loss : 0.000060
# Train Epoch : 78 | Batch Status : 440/3200 (14%) | Loss : 0.000037
# Train Epoch : 78 | Batch Status : 460/3200 (14%) | Loss : 0.000052
# Train Epoch : 78 | Batch Status : 480/3200 (15%) | Loss : 0.000181
# Train Epoch : 78 | Batch Status : 500/3200 (16%) | Loss : 0.000085
# Train Epoch : 78 | Batch Status : 520/3200 (16%) | Loss : 0.000019
# Train Epoch : 78 | Batch Status : 540/3200 (17%) | Loss : 0.000019
# Train Epoch : 78 | Batch Status : 560/3200 (18%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 580/3200 (18%) | Loss : 0.000038
# Train Epoch : 78 | Batch Status : 600/3200 (19%) | Loss : 0.000053
# Train Epoch : 78 | Batch Status : 620/3200 (19%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 640/3200 (20%) | Loss : 0.000005
# Train Epoch : 78 | Batch Status : 660/3200 (21%) | Loss : 0.000003
# Train Epoch : 78 | Batch Status : 680/3200 (21%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 700/3200 (22%) | Loss : 0.000116
# Train Epoch : 78 | Batch Status : 720/3200 (22%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 740/3200 (23%) | Loss : 0.000183
# Train Epoch : 78 | Batch Status : 760/3200 (24%) | Loss : 0.000058
# Train Epoch : 78 | Batch Status : 780/3200 (24%) | Loss : 0.000043
# Train Epoch : 78 | Batch Status : 800/3200 (25%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 820/3200 (26%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 840/3200 (26%) | Loss : 0.000576
# Train Epoch : 78 | Batch Status : 860/3200 (27%) | Loss : 0.000012
# Train Epoch : 78 | Batch Status : 880/3200 (28%) | Loss : 0.000023
# Train Epoch : 78 | Batch Status : 900/3200 (28%) | Loss : 0.000028
# Train Epoch : 78 | Batch Status : 920/3200 (29%) | Loss : 0.000053
# Train Epoch : 78 | Batch Status : 940/3200 (29%) | Loss : 0.000003
# Train Epoch : 78 | Batch Status : 960/3200 (30%) | Loss : 0.000202
# Train Epoch : 78 | Batch Status : 980/3200 (31%) | Loss : 0.000044
# Train Epoch : 78 | Batch Status : 1000/3200 (31%) | Loss : 0.000070
# Train Epoch : 78 | Batch Status : 1020/3200 (32%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 1040/3200 (32%) | Loss : 0.000121
# Train Epoch : 78 | Batch Status : 1060/3200 (33%) | Loss : 0.000015
# Train Epoch : 78 | Batch Status : 1080/3200 (34%) | Loss : 0.000014
# Train Epoch : 78 | Batch Status : 1100/3200 (34%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 1120/3200 (35%) | Loss : 0.000210
# Train Epoch : 78 | Batch Status : 1140/3200 (36%) | Loss : 0.000007
# Train Epoch : 78 | Batch Status : 1160/3200 (36%) | Loss : 0.000063
# Train Epoch : 78 | Batch Status : 1180/3200 (37%) | Loss : 0.000061
# Train Epoch : 78 | Batch Status : 1200/3200 (38%) | Loss : 0.000782
# Train Epoch : 78 | Batch Status : 1220/3200 (38%) | Loss : 0.000366
# Train Epoch : 78 | Batch Status : 1240/3200 (39%) | Loss : 0.000640
# Train Epoch : 78 | Batch Status : 1260/3200 (39%) | Loss : 0.000022
# Train Epoch : 78 | Batch Status : 1280/3200 (40%) | Loss : 0.000028
# Train Epoch : 78 | Batch Status : 1300/3200 (41%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 1320/3200 (41%) | Loss : 0.689524
# Train Epoch : 78 | Batch Status : 1340/3200 (42%) | Loss : 0.000334
# Train Epoch : 78 | Batch Status : 1360/3200 (42%) | Loss : 0.000048
# Train Epoch : 78 | Batch Status : 1380/3200 (43%) | Loss : 0.000158
# Train Epoch : 78 | Batch Status : 1400/3200 (44%) | Loss : 0.000041
# Train Epoch : 78 | Batch Status : 1420/3200 (44%) | Loss : 0.000006
# Train Epoch : 78 | Batch Status : 1440/3200 (45%) | Loss : 0.000004
# Train Epoch : 78 | Batch Status : 1460/3200 (46%) | Loss : 0.000009
# Train Epoch : 78 | Batch Status : 1480/3200 (46%) | Loss : 0.000006
# Train Epoch : 78 | Batch Status : 1500/3200 (47%) | Loss : 0.000338
# Train Epoch : 78 | Batch Status : 1520/3200 (48%) | Loss : 0.000499
# Train Epoch : 78 | Batch Status : 1540/3200 (48%) | Loss : 0.000044
# Train Epoch : 78 | Batch Status : 1560/3200 (49%) | Loss : 0.000010
# Train Epoch : 78 | Batch Status : 1580/3200 (49%) | Loss : 0.000053
# Train Epoch : 78 | Batch Status : 1600/3200 (50%) | Loss : 0.000210
# Train Epoch : 78 | Batch Status : 1620/3200 (51%) | Loss : 0.000003
# Train Epoch : 78 | Batch Status : 1640/3200 (51%) | Loss : 0.000074
# Train Epoch : 78 | Batch Status : 1660/3200 (52%) | Loss : 0.001468
# Train Epoch : 78 | Batch Status : 1680/3200 (52%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 1700/3200 (53%) | Loss : 0.000069
# Train Epoch : 78 | Batch Status : 1720/3200 (54%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 1740/3200 (54%) | Loss : 0.000007
# Train Epoch : 78 | Batch Status : 1760/3200 (55%) | Loss : 0.000061
# Train Epoch : 78 | Batch Status : 1780/3200 (56%) | Loss : 0.004485
# Train Epoch : 78 | Batch Status : 1800/3200 (56%) | Loss : 0.000004
# Train Epoch : 78 | Batch Status : 1820/3200 (57%) | Loss : 0.000003
# Train Epoch : 78 | Batch Status : 1840/3200 (58%) | Loss : 0.000859
# Train Epoch : 78 | Batch Status : 1860/3200 (58%) | Loss : 0.000043
# Train Epoch : 78 | Batch Status : 1880/3200 (59%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 1900/3200 (59%) | Loss : 0.000049
# Train Epoch : 78 | Batch Status : 1920/3200 (60%) | Loss : 0.000065
# Train Epoch : 78 | Batch Status : 1940/3200 (61%) | Loss : 0.000233
# Train Epoch : 78 | Batch Status : 1960/3200 (61%) | Loss : 0.000013
# Train Epoch : 78 | Batch Status : 1980/3200 (62%) | Loss : 0.000002
# Train Epoch : 78 | Batch Status : 2000/3200 (62%) | Loss : 0.000155
# Train Epoch : 78 | Batch Status : 2020/3200 (63%) | Loss : 0.000070
# Train Epoch : 78 | Batch Status : 2040/3200 (64%) | Loss : 0.000008
# Train Epoch : 78 | Batch Status : 2060/3200 (64%) | Loss : 0.000015
# Train Epoch : 78 | Batch Status : 2080/3200 (65%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 2100/3200 (66%) | Loss : 0.000033
# Train Epoch : 78 | Batch Status : 2120/3200 (66%) | Loss : 0.000118
# Train Epoch : 78 | Batch Status : 2140/3200 (67%) | Loss : 0.000038
# Train Epoch : 78 | Batch Status : 2160/3200 (68%) | Loss : 0.000138
# Train Epoch : 78 | Batch Status : 2180/3200 (68%) | Loss : 0.000033
# Train Epoch : 78 | Batch Status : 2200/3200 (69%) | Loss : 0.000018
# Train Epoch : 78 | Batch Status : 2220/3200 (69%) | Loss : 0.000392
# Train Epoch : 78 | Batch Status : 2240/3200 (70%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 2260/3200 (71%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 2280/3200 (71%) | Loss : 0.000024
# Train Epoch : 78 | Batch Status : 2300/3200 (72%) | Loss : 0.000118
# Train Epoch : 78 | Batch Status : 2320/3200 (72%) | Loss : 0.000197
# Train Epoch : 78 | Batch Status : 2340/3200 (73%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 2360/3200 (74%) | Loss : 0.000026
# Train Epoch : 78 | Batch Status : 2380/3200 (74%) | Loss : 0.001136
# Train Epoch : 78 | Batch Status : 2400/3200 (75%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 2420/3200 (76%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 2440/3200 (76%) | Loss : 0.000009
# Train Epoch : 78 | Batch Status : 2460/3200 (77%) | Loss : 0.000090
# Train Epoch : 78 | Batch Status : 2480/3200 (78%) | Loss : 0.000588
# Train Epoch : 78 | Batch Status : 2500/3200 (78%) | Loss : 0.000390
# Train Epoch : 78 | Batch Status : 2520/3200 (79%) | Loss : 0.000011
# Train Epoch : 78 | Batch Status : 2540/3200 (79%) | Loss : 0.000130
# Train Epoch : 78 | Batch Status : 2560/3200 (80%) | Loss : 0.000000
# Train Epoch : 78 | Batch Status : 2580/3200 (81%) | Loss : 0.000072
# Train Epoch : 78 | Batch Status : 2600/3200 (81%) | Loss : 0.000007
# Train Epoch : 78 | Batch Status : 2620/3200 (82%) | Loss : 0.000002
# Train Epoch : 78 | Batch Status : 2640/3200 (82%) | Loss : 0.000004
# Train Epoch : 78 | Batch Status : 2660/3200 (83%) | Loss : 0.000008
# Train Epoch : 78 | Batch Status : 2680/3200 (84%) | Loss : 0.000004
# Train Epoch : 78 | Batch Status : 2700/3200 (84%) | Loss : 0.000487
# Train Epoch : 78 | Batch Status : 2720/3200 (85%) | Loss : 0.000022
# Train Epoch : 78 | Batch Status : 2740/3200 (86%) | Loss : 0.000058
# Train Epoch : 78 | Batch Status : 2760/3200 (86%) | Loss : 0.000268
# Train Epoch : 78 | Batch Status : 2780/3200 (87%) | Loss : 0.000231
# Train Epoch : 78 | Batch Status : 2800/3200 (88%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 2820/3200 (88%) | Loss : 0.000237
# Train Epoch : 78 | Batch Status : 2840/3200 (89%) | Loss : 0.000029
# Train Epoch : 78 | Batch Status : 2860/3200 (89%) | Loss : 0.000001
# Train Epoch : 78 | Batch Status : 2880/3200 (90%) | Loss : 0.000104
# Train Epoch : 78 | Batch Status : 2900/3200 (91%) | Loss : 0.000017
# Train Epoch : 78 | Batch Status : 2920/3200 (91%) | Loss : 0.000018
# Train Epoch : 78 | Batch Status : 2940/3200 (92%) | Loss : 0.000053
# Train Epoch : 78 | Batch Status : 2960/3200 (92%) | Loss : 0.000929
# Train Epoch : 78 | Batch Status : 2980/3200 (93%) | Loss : 0.000370
# Train Epoch : 78 | Batch Status : 3000/3200 (94%) | Loss : 0.000200
# Train Epoch : 78 | Batch Status : 3020/3200 (94%) | Loss : 0.000003
# Train Epoch : 78 | Batch Status : 3040/3200 (95%) | Loss : 0.000323
# Train Epoch : 78 | Batch Status : 3060/3200 (96%) | Loss : 0.000005
# Train Epoch : 78 | Batch Status : 3080/3200 (96%) | Loss : 0.000468
# Train Epoch : 78 | Batch Status : 3100/3200 (97%) | Loss : 0.000278
# Train Epoch : 78 | Batch Status : 3120/3200 (98%) | Loss : 0.000868
# Train Epoch : 78 | Batch Status : 3140/3200 (98%) | Loss : 0.000089
# Train Epoch : 78 | Batch Status : 3160/3200 (99%) | Loss : 0.000105
# Train Epoch : 78 | Batch Status : 3180/3200 (99%) | Loss : 0.000015
# Training time: 0m 4s
# ==================
# Validation set: Average loss : 0.0005, Accuracy : 3198/3200(100%)
# Tesing time: 0m 6s
# Train Epoch : 79 | Batch Status : 0/3200 (0%) | Loss : 0.000180
# Train Epoch : 79 | Batch Status : 20/3200 (1%) | Loss : 0.000003
# Train Epoch : 79 | Batch Status : 40/3200 (1%) | Loss : 0.000031
# Train Epoch : 79 | Batch Status : 60/3200 (2%) | Loss : 0.000033
# Train Epoch : 79 | Batch Status : 80/3200 (2%) | Loss : 0.000188
# Train Epoch : 79 | Batch Status : 100/3200 (3%) | Loss : 0.000044
# Train Epoch : 79 | Batch Status : 120/3200 (4%) | Loss : 0.000025
# Train Epoch : 79 | Batch Status : 140/3200 (4%) | Loss : 0.000002
# Train Epoch : 79 | Batch Status : 160/3200 (5%) | Loss : 0.000015
# Train Epoch : 79 | Batch Status : 180/3200 (6%) | Loss : 0.000048
# Train Epoch : 79 | Batch Status : 200/3200 (6%) | Loss : 0.000376
# Train Epoch : 79 | Batch Status : 220/3200 (7%) | Loss : 0.002813
# Train Epoch : 79 | Batch Status : 240/3200 (8%) | Loss : 0.000281
# Train Epoch : 79 | Batch Status : 260/3200 (8%) | Loss : 0.000265
# Train Epoch : 79 | Batch Status : 280/3200 (9%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 300/3200 (9%) | Loss : 0.000019
# Train Epoch : 79 | Batch Status : 320/3200 (10%) | Loss : 0.000057
# Train Epoch : 79 | Batch Status : 340/3200 (11%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 360/3200 (11%) | Loss : 0.000527
# Train Epoch : 79 | Batch Status : 380/3200 (12%) | Loss : 0.000235
# Train Epoch : 79 | Batch Status : 400/3200 (12%) | Loss : 0.000003
# Train Epoch : 79 | Batch Status : 420/3200 (13%) | Loss : 0.000287
# Train Epoch : 79 | Batch Status : 440/3200 (14%) | Loss : 0.000002
# Train Epoch : 79 | Batch Status : 460/3200 (14%) | Loss : 0.000003
# Train Epoch : 79 | Batch Status : 480/3200 (15%) | Loss : 0.000004
# Train Epoch : 79 | Batch Status : 500/3200 (16%) | Loss : 0.000228
# Train Epoch : 79 | Batch Status : 520/3200 (16%) | Loss : 0.000523
# Train Epoch : 79 | Batch Status : 540/3200 (17%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 560/3200 (18%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 580/3200 (18%) | Loss : 0.000116
# Train Epoch : 79 | Batch Status : 600/3200 (19%) | Loss : 0.000134
# Train Epoch : 79 | Batch Status : 620/3200 (19%) | Loss : 0.000002
# Train Epoch : 79 | Batch Status : 640/3200 (20%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 660/3200 (21%) | Loss : 0.000007
# Train Epoch : 79 | Batch Status : 680/3200 (21%) | Loss : 0.000012
# Train Epoch : 79 | Batch Status : 700/3200 (22%) | Loss : 0.000006
# Train Epoch : 79 | Batch Status : 720/3200 (22%) | Loss : 0.000048
# Train Epoch : 79 | Batch Status : 740/3200 (23%) | Loss : 0.000861
# Train Epoch : 79 | Batch Status : 760/3200 (24%) | Loss : 0.000537
# Train Epoch : 79 | Batch Status : 780/3200 (24%) | Loss : 0.000005
# Train Epoch : 79 | Batch Status : 800/3200 (25%) | Loss : 0.000257
# Train Epoch : 79 | Batch Status : 820/3200 (26%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 840/3200 (26%) | Loss : 0.000463
# Train Epoch : 79 | Batch Status : 860/3200 (27%) | Loss : 0.000210
# Train Epoch : 79 | Batch Status : 880/3200 (28%) | Loss : 0.000211
# Train Epoch : 79 | Batch Status : 900/3200 (28%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 920/3200 (29%) | Loss : 0.000067
# Train Epoch : 79 | Batch Status : 940/3200 (29%) | Loss : 0.000001
# Train Epoch : 79 | Batch Status : 960/3200 (30%) | Loss : 0.000112
# Train Epoch : 79 | Batch Status : 980/3200 (31%) | Loss : 0.000050
# Train Epoch : 79 | Batch Status : 1000/3200 (31%) | Loss : 0.000135
# Train Epoch : 79 | Batch Status : 1020/3200 (32%) | Loss : 0.000070
# Train Epoch : 79 | Batch Status : 1040/3200 (32%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 1060/3200 (33%) | Loss : 0.000001
# Train Epoch : 79 | Batch Status : 1080/3200 (34%) | Loss : 0.000037
# Train Epoch : 79 | Batch Status : 1100/3200 (34%) | Loss : 0.000003
# Train Epoch : 79 | Batch Status : 1120/3200 (35%) | Loss : 0.000177
# Train Epoch : 79 | Batch Status : 1140/3200 (36%) | Loss : 0.000024
# Train Epoch : 79 | Batch Status : 1160/3200 (36%) | Loss : 0.000590
# Train Epoch : 79 | Batch Status : 1180/3200 (37%) | Loss : 0.000082
# Train Epoch : 79 | Batch Status : 1200/3200 (38%) | Loss : 0.000816
# Train Epoch : 79 | Batch Status : 1220/3200 (38%) | Loss : 0.000366
# Train Epoch : 79 | Batch Status : 1240/3200 (39%) | Loss : 0.000040
# Train Epoch : 79 | Batch Status : 1260/3200 (39%) | Loss : 0.000322
# Train Epoch : 79 | Batch Status : 1280/3200 (40%) | Loss : 0.000604
# Train Epoch : 79 | Batch Status : 1300/3200 (41%) | Loss : 0.000005
# Train Epoch : 79 | Batch Status : 1320/3200 (41%) | Loss : 0.000189
# Train Epoch : 79 | Batch Status : 1340/3200 (42%) | Loss : 0.000180
# Train Epoch : 79 | Batch Status : 1360/3200 (42%) | Loss : 0.000141
# Train Epoch : 79 | Batch Status : 1380/3200 (43%) | Loss : 0.000060
# Train Epoch : 79 | Batch Status : 1400/3200 (44%) | Loss : 0.000068
# Train Epoch : 79 | Batch Status : 1420/3200 (44%) | Loss : 0.000360
# Train Epoch : 79 | Batch Status : 1440/3200 (45%) | Loss : 0.000045
# Train Epoch : 79 | Batch Status : 1460/3200 (46%) | Loss : 0.000001
# Train Epoch : 79 | Batch Status : 1480/3200 (46%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 1500/3200 (47%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 1520/3200 (48%) | Loss : 0.000052
# Train Epoch : 79 | Batch Status : 1540/3200 (48%) | Loss : 0.000014
# Train Epoch : 79 | Batch Status : 1560/3200 (49%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 1580/3200 (49%) | Loss : 0.001299
# Train Epoch : 79 | Batch Status : 1600/3200 (50%) | Loss : 0.000116
# Train Epoch : 79 | Batch Status : 1620/3200 (51%) | Loss : 0.000002
# Train Epoch : 79 | Batch Status : 1640/3200 (51%) | Loss : 0.000005
# Train Epoch : 79 | Batch Status : 1660/3200 (52%) | Loss : 0.000753
# Train Epoch : 79 | Batch Status : 1680/3200 (52%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 1700/3200 (53%) | Loss : 0.000228
# Train Epoch : 79 | Batch Status : 1720/3200 (54%) | Loss : 0.000158
# Train Epoch : 79 | Batch Status : 1740/3200 (54%) | Loss : 0.000023
# Train Epoch : 79 | Batch Status : 1760/3200 (55%) | Loss : 0.000116
# Train Epoch : 79 | Batch Status : 1780/3200 (56%) | Loss : 0.000087
# Train Epoch : 79 | Batch Status : 1800/3200 (56%) | Loss : 0.000100
# Train Epoch : 79 | Batch Status : 1820/3200 (57%) | Loss : 0.000152
# Train Epoch : 79 | Batch Status : 1840/3200 (58%) | Loss : 0.000051
# Train Epoch : 79 | Batch Status : 1860/3200 (58%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 1880/3200 (59%) | Loss : 0.000562
# Train Epoch : 79 | Batch Status : 1900/3200 (59%) | Loss : 0.000023
# Train Epoch : 79 | Batch Status : 1920/3200 (60%) | Loss : 0.000099
# Train Epoch : 79 | Batch Status : 1940/3200 (61%) | Loss : 0.000076
# Train Epoch : 79 | Batch Status : 1960/3200 (61%) | Loss : 0.000003
# Train Epoch : 79 | Batch Status : 1980/3200 (62%) | Loss : 0.000456
# Train Epoch : 79 | Batch Status : 2000/3200 (62%) | Loss : 0.739122
# Train Epoch : 79 | Batch Status : 2020/3200 (63%) | Loss : 0.000189
# Train Epoch : 79 | Batch Status : 2040/3200 (64%) | Loss : 0.000019
# Train Epoch : 79 | Batch Status : 2060/3200 (64%) | Loss : 0.000033
# Train Epoch : 79 | Batch Status : 2080/3200 (65%) | Loss : 0.000264
# Train Epoch : 79 | Batch Status : 2100/3200 (66%) | Loss : 0.000001
# Train Epoch : 79 | Batch Status : 2120/3200 (66%) | Loss : 0.000032
# Train Epoch : 79 | Batch Status : 2140/3200 (67%) | Loss : 0.000369
# Train Epoch : 79 | Batch Status : 2160/3200 (68%) | Loss : 0.000026
# Train Epoch : 79 | Batch Status : 2180/3200 (68%) | Loss : 0.000065
# Train Epoch : 79 | Batch Status : 2200/3200 (69%) | Loss : 0.000047
# Train Epoch : 79 | Batch Status : 2220/3200 (69%) | Loss : 0.000012
# Train Epoch : 79 | Batch Status : 2240/3200 (70%) | Loss : 0.000028
# Train Epoch : 79 | Batch Status : 2260/3200 (71%) | Loss : 0.000009
# Train Epoch : 79 | Batch Status : 2280/3200 (71%) | Loss : 0.000311
# Train Epoch : 79 | Batch Status : 2300/3200 (72%) | Loss : 0.000001
# Train Epoch : 79 | Batch Status : 2320/3200 (72%) | Loss : 0.001627
# Train Epoch : 79 | Batch Status : 2340/3200 (73%) | Loss : 0.001392
# Train Epoch : 79 | Batch Status : 2360/3200 (74%) | Loss : 0.000203
# Train Epoch : 79 | Batch Status : 2380/3200 (74%) | Loss : 0.000608
# Train Epoch : 79 | Batch Status : 2400/3200 (75%) | Loss : 0.000901
# Train Epoch : 79 | Batch Status : 2420/3200 (76%) | Loss : 0.000060
# Train Epoch : 79 | Batch Status : 2440/3200 (76%) | Loss : 0.000048
# Train Epoch : 79 | Batch Status : 2460/3200 (77%) | Loss : 0.000090
# Train Epoch : 79 | Batch Status : 2480/3200 (78%) | Loss : 0.000050
# Train Epoch : 79 | Batch Status : 2500/3200 (78%) | Loss : 0.000013
# Train Epoch : 79 | Batch Status : 2520/3200 (79%) | Loss : 0.000006
# Train Epoch : 79 | Batch Status : 2540/3200 (79%) | Loss : 0.000020
# Train Epoch : 79 | Batch Status : 2560/3200 (80%) | Loss : 0.000000
# Train Epoch : 79 | Batch Status : 2580/3200 (81%) | Loss : 0.000123
# ...
# Processing the image number 381 .....
# Processing the image number 382 .....
# Processing the image number 383 .....
# Processing the image number 384 .....
# Processing the image number 385 .....
# Processing the image number 386 .....
# Processing the image number 387 .....
# Processing the image number 388 .....
# Processing the image number 389 .....
# Processing the image number 390 .....
# Processing the image number 391 .....
# Processing the image number 392 .....
# Processing the image number 393 .....
# Processing the image number 394 .....
# Processing the image number 395 .....
# Processing the image number 396 .....
# Processing the image number 397 .....
# Processing the image number 398 .....
# Processing the image number 399 .....
# Processing the image number 400 .....
# Processing the image number 401 .....
# Processing the image number 402 .....
# Processing the image number 403 .....
# Processing the image number 404 .....
# Processing the image number 405 .....
# Processing the image number 406 .....
# Processing the image number 407 .....
# Processing the image number 408 .....
# Processing the image number 409 .....
# Processing the image number 410 .....
# Processing the image number 411 .....
# Processing the image number 412 .....
# Processing the image number 413 .....
# Processing the image number 414 .....
# Processing the image number 415 .....
# Processing the image number 416 .....
# Processing the image number 417 .....
# Processing the image number 418 .....
# Processing the image number 419 .....
# Processing the image number 420 .....
# Processing the image number 421 .....
# Processing the image number 422 .....
# Processing the image number 423 .....
# Processing the image number 424 .....
# Processing the image number 425 .....
# Processing the image number 426 .....
# Processing the image number 427 .....
# Processing the image number 428 .....
# Processing the image number 429 .....
# Processing the image number 430 .....
# Processing the image number 431 .....
# Processing the image number 432 .....
# Processing the image number 433 .....
# Processing the image number 434 .....
# Processing the image number 435 .....
# Processing the image number 436 .....
# Processing the image number 437 .....
# Processing the image number 438 .....
# Processing the image number 439 .....
# Processing the image number 440 .....
# Processing the image number 441 .....
# Processing the image number 442 .....
# Processing the image number 443 .....
# Processing the image number 444 .....
# Processing the image number 445 .....
# Processing the image number 446 .....
# Processing the image number 447 .....
# Processing the image number 448 .....
# Processing the image number 449 .....
# Processing the image number 450 .....
# Processing the image number 451 .....
# Processing the image number 452 .....
# Processing the image number 453 .....
# Processing the image number 454 .....
# Processing the image number 455 .....
# Processing the image number 456 .....
# Processing the image number 457 .....
# Processing the image number 458 .....
# Processing the image number 459 .....
# Processing the image number 460 .....
# Processing the image number 461 .....
# Processing the image number 462 .....
# Processing the image number 463 .....
# Processing the image number 464 .....
# Processing the image number 465 .....
# Processing the image number 466 .....
# Processing the image number 467 .....
# Processing the image number 468 .....
# Processing the image number 469 .....
# Processing the image number 470 .....
# Processing the image number 471 .....
# Processing the image number 472 .....
# Processing the image number 473 .....
# Processing the image number 474 .....
# Processing the image number 475 .....
# Processing the image number 476 .....
# Processing the image number 477 .....
# Processing the image number 478 .....
# Processing the image number 479 .....
# Processing the image number 480 .....
# Processing the image number 481 .....
# Processing the image number 482 .....
# Processing the image number 483 .....
# Processing the image number 484 .....
# Processing the image number 485 .....
# Processing the image number 486 .....
# Processing the image number 487 .....
# Processing the image number 488 .....
# Processing the image number 489 .....
# Processing the image number 490 .....
# Processing the image number 491 .....
# Processing the image number 492 .....
# Processing the image number 493 .....
# Processing the image number 494 .....
# Processing the image number 495 .....
# Processing the image number 496 .....
# Processing the image number 497 .....
# Processing the image number 498 .....
# Processing the image number 499 .....
# Processing the image number 500 .....
# Processing the image number 501 .....
# Processing the image number 502 .....
# Processing the image number 503 .....
# Processing the image number 504 .....
# Processing the image number 505 .....
# Processing the image number 506 .....
# Processing the image number 507 .....
# Processing the image number 508 .....
# Processing the image number 509 .....
# Processing the image number 510 .....
# Processing the image number 511 .....
# Processing the image number 512 .....
# Processing the image number 513 .....
# Processing the image number 514 .....
# Processing the image number 515 .....
# Processing the image number 516 .....
# Processing the image number 517 .....
# Processing the image number 518 .....
# Processing the image number 519 .....
# Processing the image number 520 .....
# Processing the image number 521 .....
# Processing the image number 522 .....
# Processing the image number 523 .....
# Processing the image number 524 .....
# Processing the image number 525 .....
# Processing the image number 526 .....
# Processing the image number 527 .....
# Processing the image number 528 .....
# Processing the image number 529 .....
# Processing the image number 530 .....
# Processing the image number 531 .....
# Processing the image number 532 .....
# Processing the image number 533 .....
# Processing the image number 534 .....
# Processing the image number 535 .....
# Processing the image number 536 .....
# Processing the image number 537 .....
# Processing the image number 538 .....
# Processing the image number 539 .....
# Processing the image number 540 .....
# Processing the image number 541 .....
# Processing the image number 542 .....
# Processing the image number 543 .....
# Processing the image number 544 .....
# Processing the image number 545 .....
# Processing the image number 546 .....
# Processing the image number 547 .....
# Processing the image number 548 .....
# Processing the image number 549 .....
# Processing the image number 550 .....
# Processing the image number 551 .....
# Processing the image number 552 .....
# Processing the image number 553 .....
# Processing the image number 554 .....
# Processing the image number 555 .....
# Processing the image number 556 .....
# Processing the image number 557 .....
# Processing the image number 558 .....
# Processing the image number 559 .....
# Processing the image number 560 .....
# Processing the image number 561 .....
# Processing the image number 562 .....
# Processing the image number 563 .....
# Processing the image number 564 .....
# Processing the image number 565 .....
# Processing the image number 566 .....
# Processing the image number 567 .....
# Processing the image number 568 .....
# Processing the image number 569 .....
# Processing the image number 570 .....
# Processing the image number 571 .....
# Processing the image number 572 .....
# Processing the image number 573 .....
# Processing the image number 574 .....
# Processing the image number 575 .....
# Processing the image number 576 .....
# Processing the image number 577 .....
# Processing the image number 578 .....
# Processing the image number 579 .....
# Processing the image number 580 .....
# Processing the image number 581 .....
# Processing the image number 582 .....
# Processing the image number 583 .....
# Processing the image number 584 .....
# Processing the image number 585 .....
# Processing the image number 586 .....
# Processing the image number 587 .....
# Processing the image number 588 .....
# Processing the image number 589 .....
# Processing the image number 590 .....
# Processing the image number 591 .....
# Processing the image number 592 .....
# Processing the image number 593 .....
# Processing the image number 594 .....
# Processing the image number 595 .....
# Processing the image number 596 .....
# Processing the image number 597 .....
# Processing the image number 598 .....
# Processing the image number 599 .....
# Processing the image number 600 .....
# Processing the image number 601 .....
# Processing the image number 602 .....
# Processing the image number 603 .....
# Processing the image number 604 .....
# Processing the image number 605 .....
# Processing the image number 606 .....
# Processing the image number 607 .....
# Processing the image number 608 .....
# Processing the image number 609 .....
# Processing the image number 610 .....
# Processing the image number 611 .....
# Processing the image number 612 .....
# Processing the image number 613 .....
# Processing the image number 614 .....
# Processing the image number 615 .....
# Processing the image number 616 .....
# Processing the image number 617 .....
# Processing the image number 618 .....
# Processing the image number 619 .....
# Processing the image number 620 .....
# Processing the image number 621 .....
# Processing the image number 622 .....
# Processing the image number 623 .....
# Processing the image number 624 .....
# Processing the image number 625 .....
# Processing the image number 626 .....
# Processing the image number 627 .....
# Processing the image number 628 .....
# Processing the image number 629 .....
# Processing the image number 630 .....
# Processing the image number 631 .....
# Processing the image number 632 .....
# Processing the image number 633 .....
# Processing the image number 634 .....
# Processing the image number 635 .....
# Processing the image number 636 .....
# Processing the image number 637 .....
# Processing the image number 638 .....
# Processing the image number 639 .....
# Processing the image number 640 .....
# Processing the image number 641 .....
# Processing the image number 642 .....
# Processing the image number 643 .....
# Processing the image number 644 .....
# Processing the image number 645 .....
# Processing the image number 646 .....
# Processing the image number 647 .....
# Processing the image number 648 .....
# Processing the image number 649 .....
# Processing the image number 650 .....
# Processing the image number 651 .....
# Processing the image number 652 .....
# Processing the image number 653 .....
# Processing the image number 654 .....
# Processing the image number 655 .....
# Processing the image number 656 .....
# Processing the image number 657 .....
# Processing the image number 658 .....
# Processing the image number 659 .....
# Processing the image number 660 .....
# Processing the image number 661 .....
# Processing the image number 662 .....
# Processing the image number 663 .....
# Processing the image number 664 .....
# Processing the image number 665 .....
# Processing the image number 666 .....
# Processing the image number 667 .....
# Processing the image number 668 .....
# Processing the image number 669 .....
# Processing the image number 670 .....
# Processing the image number 671 .....
# Processing the image number 672 .....
# Processing the image number 673 .....
# Processing the image number 674 .....
# Processing the image number 675 .....
# Processing the image number 676 .....
# Processing the image number 677 .....
# Processing the image number 678 .....
# Processing the image number 679 .....
# Processing the image number 680 .....
# Processing the image number 681 .....
# Processing the image number 682 .....
# Processing the image number 683 .....
# Processing the image number 684 .....
# Processing the image number 685 .....
# Processing the image number 686 .....
# Processing the image number 687 .....
# Processing the image number 688 .....
# Processing the image number 689 .....
# Processing the image number 690 .....
# Processing the image number 691 .....
# Processing the image number 692 .....
# Processing the image number 693 .....
# Processing the image number 694 .....
# Processing the image number 695 .....
# Processing the image number 696 .....
# Processing the image number 697 .....
# Processing the image number 698 .....
# Processing the image number 699 .....
# Processing the image number 700 .....
# Processing the image number 701 .....
# Processing the image number 702 .....
# Processing the image number 703 .....
# Processing the image number 704 .....
# Processing the image number 705 .....
# Processing the image number 706 .....
# Processing the image number 707 .....
# Processing the image number 708 .....
# Processing the image number 709 .....
# Processing the image number 710 .....
# Processing the image number 711 .....
# Processing the image number 712 .....
# Processing the image number 713 .....
# Processing the image number 714 .....
# Processing the image number 715 .....
# Processing the image number 716 .....
# Processing the image number 717 .....
# Processing the image number 718 .....
# Processing the image number 719 .....
# Processing the image number 720 .....
# Processing the image number 721 .....
# Processing the image number 722 .....
# Processing the image number 723 .....
# Processing the image number 724 .....
# Processing the image number 725 .....
# Processing the image number 726 .....
# Processing the image number 727 .....
# Processing the image number 728 .....
# Processing the image number 729 .....
# Processing the image number 730 .....
# Processing the image number 731 .....
# Processing the image number 732 .....
# Processing the image number 733 .....
# Processing the image number 734 .....
# Processing the image number 735 .....
# Processing the image number 736 .....
# Processing the image number 737 .....
# Processing the image number 738 .....
# Processing the image number 739 .....
# Processing the image number 740 .....
# Processing the image number 741 .....
# Processing the image number 742 .....
# Processing the image number 743 .....
# Processing the image number 744 .....
# Processing the image number 745 .....
# Processing the image number 746 .....
# Processing the image number 747 .....
# Processing the image number 748 .....
# Processing the image number 749 .....
# Processing the image number 750 .....
# Processing the image number 751 .....
# Processing the image number 752 .....
# Processing the image number 753 .....
# Processing the image number 754 .....
# Processing the image number 755 .....
# Processing the image number 756 .....
# Processing the image number 757 .....
# Processing the image number 758 .....
# Processing the image number 759 .....
# Processing the image number 760 .....
# Processing the image number 761 .....
# Processing the image number 762 .....
# Processing the image number 763 .....
# Processing the image number 764 .....
# Processing the image number 765 .....
# Processing the image number 766 .....
# Processing the image number 767 .....
# Processing the image number 768 .....
# Processing the image number 769 .....
# Processing the image number 770 .....
# Processing the image number 771 .....
# Processing the image number 772 .....
# Processing the image number 773 .....
# Processing the image number 774 .....
# Processing the image number 775 .....
# Processing the image number 776 .....
# Processing the image number 777 .....
# Processing the image number 778 .....
# Processing the image number 779 .....
# Processing the image number 780 .....
# Processing the image number 781 .....
# Processing the image number 782 .....
# Processing the image number 783 .....
# Processing the image number 784 .....
# Processing the image number 785 .....
# Processing the image number 786 .....
# Processing the image number 787 .....
# Processing the image number 788 .....
# Processing the image number 789 .....
# Processing the image number 790 .....
# Processing the image number 791 .....
# Processing the image number 792 .....
# Processing the image number 793 .....
# Processing the image number 794 .....
# Processing the image number 795 .....
# Processing the image number 796 .....
# Processing the image number 797 .....
# Processing the image number 798 .....
# Processing the image number 799 .....
# Evaluation completed. The submittion file has been saved.
